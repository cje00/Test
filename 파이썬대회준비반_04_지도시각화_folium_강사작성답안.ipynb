# %% [markdown]
# # 지도를 이용한 데이터 시각화하기
# * folium 라이브러리 활용
# * 지도에 표시하기 위한 정보 - 위도, 경도

# %%
import folium

# %% [markdown]
# ## 지도를 띄우기
# * Map() 함수 사용

# %%
# 37.5544988!4d127.0404364 구글지도에서 주소창의 끝부분의 값을 참고하기
m = folium.Map(location=[37.5544988,127.0404364])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c4e0e1e5a5fd304bb7935fdc3140b00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c4e0e1e5a5fd304bb7935fdc3140b00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5c4e0e1e5a5fd304bb7935fdc3140b00 = L.map(
#                 &quot;map_5c4e0e1e5a5fd304bb7935fdc3140b00&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67db91b5346c852a6e4e0ff8d5950be3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c4e0e1e5a5fd304bb7935fdc3140b00);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 확대하기 (zoom_start 옵션 사용)
m = folium.Map(location=[37.5544988,127.0404364], zoom_start = 16)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec666bc5feeb5f2377e70f39e7b5757a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec666bc5feeb5f2377e70f39e7b5757a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ec666bc5feeb5f2377e70f39e7b5757a = L.map(
#                 &quot;map_ec666bc5feeb5f2377e70f39e7b5757a&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93378a43496316c0892b49767dd0511f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec666bc5feeb5f2377e70f39e7b5757a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도테마 설정하기 (tiles = '')
# OpenStreetMap(기본테마), Stamen Terrain, Stamen Toner, cartodb positron
m = folium.Map(location=[37.5544988,127.0404364], zoom_start = 16, tiles='Stamen Terrain')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c46a7c18c4029b174aeffc3216c9851 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c46a7c18c4029b174aeffc3216c9851&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6c46a7c18c4029b174aeffc3216c9851 = L.map(
#                 &quot;map_6c46a7c18c4029b174aeffc3216c9851&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_277e3214b4d9704fde567900f3155e42 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c46a7c18c4029b174aeffc3216c9851);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 지도에 Marker 표시하기
# * popup : 마우스 클릭시 표시되는 문구
# * icon : 표시할 아이콘 지정
# * tooltip : 마우스 오버시 표시되는 문구

# %%
m = folium.Map(location=[37.5544988,127.0404364], zoom_start = 15)

# 성동 4차산업혁명체험센터 
folium.Marker(location = [37.5544988,127.0404364],
              icon = folium.Icon(color = 'red', icon='heart'),
              popup = '성동 4차산업혁명체험센터',
              ).add_to(m)

# 우리집
folium.Marker(location = [37.5443878,127.0374424],
              icon = folium.Icon(color = 'red', icon='flag'),
              popup = '우리집'
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5082fd3355106b51e6323a529aa3bed3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5082fd3355106b51e6323a529aa3bed3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5082fd3355106b51e6323a529aa3bed3 = L.map(
#                 &quot;map_5082fd3355106b51e6323a529aa3bed3&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4dde461f660ff47e84cc9fcf5136d220 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5082fd3355106b51e6323a529aa3bed3);
#
#
#             var marker_804dca70cdf149b19c029aaa6c79684a = L.marker(
#                 [37.5544988, 127.0404364],
#                 {}
#             ).addTo(map_5082fd3355106b51e6323a529aa3bed3);
#
#
#             var icon_bbc53855145830e9361c333042f93390 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_804dca70cdf149b19c029aaa6c79684a.setIcon(icon_bbc53855145830e9361c333042f93390);
#
#
#         var popup_6f534617ec22bf2f4f33c4c83e2a21fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_61f3631cb1f6c589e2a6f65e22f7caf3 = $(`&lt;div id=&quot;html_61f3631cb1f6c589e2a6f65e22f7caf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성동 4차산업혁명체험센터&lt;/div&gt;`)[0];
#             popup_6f534617ec22bf2f4f33c4c83e2a21fa.setContent(html_61f3631cb1f6c589e2a6f65e22f7caf3);
#
#
#         marker_804dca70cdf149b19c029aaa6c79684a.bindPopup(popup_6f534617ec22bf2f4f33c4c83e2a21fa)
#         ;
#
#
#
#
#             var marker_2bd96f82f94573237b022ca5465d9648 = L.marker(
#                 [37.5443878, 127.0374424],
#                 {}
#             ).addTo(map_5082fd3355106b51e6323a529aa3bed3);
#
#
#             var icon_212ba70be8fbd6ea6a6cc3bc55f414d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bd96f82f94573237b022ca5465d9648.setIcon(icon_212ba70be8fbd6ea6a6cc3bc55f414d0);
#
#
#         var popup_4c3b89f4f8b490822432b4a92b83690d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b0832e5f8e95cc2036c4c8c01e98fb5c = $(`&lt;div id=&quot;html_b0832e5f8e95cc2036c4c8c01e98fb5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;우리집&lt;/div&gt;`)[0];
#             popup_4c3b89f4f8b490822432b4a92b83690d.setContent(html_b0832e5f8e95cc2036c4c8c01e98fb5c);
#
#
#         marker_2bd96f82f94573237b022ca5465d9648.bindPopup(popup_4c3b89f4f8b490822432b4a92b83690d)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## CircleMarker(서클마커) 표시하기

# %%
m = folium.Map(location=[37.5544988,127.0404364], zoom_start = 15)

# 성동 4차산업혁명체험센터 
folium.Marker(location = [37.5544988,127.0404364],
              icon = folium.Icon(color = 'red', icon='heart'),
              popup = '성동 4차산업혁명체험센터',
              ).add_to(m)

folium.CircleMarker(
    location = [37.5544988,127.0404364],
    radius = 100, 
    fill = True,
    color = 'blue',
    fill_color = '#ff3366'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36561c4f7a7986ce6b1d748a6192b528 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36561c4f7a7986ce6b1d748a6192b528&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_36561c4f7a7986ce6b1d748a6192b528 = L.map(
#                 &quot;map_36561c4f7a7986ce6b1d748a6192b528&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_178e32e51af305cf3b7c6ca6b44380af = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36561c4f7a7986ce6b1d748a6192b528);
#
#
#             var marker_86c1bb9db6ac3960070e9671f88e7f55 = L.marker(
#                 [37.5544988, 127.0404364],
#                 {}
#             ).addTo(map_36561c4f7a7986ce6b1d748a6192b528);
#
#
#             var icon_af4478b22452eaa31ca089239c497d58 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86c1bb9db6ac3960070e9671f88e7f55.setIcon(icon_af4478b22452eaa31ca089239c497d58);
#
#
#         var popup_9203884670ad75fe3546350ff348bcf7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_89d377eba5abbd8c2ce5665e52ecadf6 = $(`&lt;div id=&quot;html_89d377eba5abbd8c2ce5665e52ecadf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성동 4차산업혁명체험센터&lt;/div&gt;`)[0];
#             popup_9203884670ad75fe3546350ff348bcf7.setContent(html_89d377eba5abbd8c2ce5665e52ecadf6);
#
#
#         marker_86c1bb9db6ac3960070e9671f88e7f55.bindPopup(popup_9203884670ad75fe3546350ff348bcf7)
#         ;
#
#
#
#
#             var circle_marker_fb205d94b53384e609da5d922ff046b3 = L.circleMarker(
#                 [37.5544988, 127.0404364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff3366&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36561c4f7a7986ce6b1d748a6192b528);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 성동구 CCTV 위치를 지도로 나타내기

# %%
import pandas as pd

df = pd.read_csv('서울시 성동구 (안심이) CCTV 설치 현황.csv', encoding='cp949')
df.head()
# Out:
#    자치구                        안심 주소 CCTV 용도         위도          경도  CCTV 수량  \
# 0  성동구           G044_(고정2)6_골목길(동)    미세먼지  37.534733  127.056801        1
# 1  성동구         **C362_(회전)_성수동1가 95    미세먼지  37.539028  127.047371        1
# 2  성동구             G049_(고정2)3_자그마치    미세먼지  37.543083  127.055290        1
# 3  성동구  ***C232_(회전)_성수1가1동 656-318    미세먼지  37.545624  127.045738        1
# 4  성동구          G010_(고정2)3_성수동갈비골목    미세먼지  37.547321  127.042847        1
#
#         수정 일시
# 0  2021-12-07
# 1  2021-12-07
# 2  2021-12-07
# 3  2021-12-07
# 4  2021-12-07

# %%
df
# Out:
#       자치구                           안심 주소 CCTV 용도         위도          경도  \
# 0     성동구              G044_(고정2)6_골목길(동)    미세먼지  37.534733  127.056801
# 1     성동구            **C362_(회전)_성수동1가 95    미세먼지  37.539028  127.047371
# 2     성동구                G049_(고정2)3_자그마치    미세먼지  37.543083  127.055290
# 3     성동구     ***C232_(회전)_성수1가1동 656-318    미세먼지  37.545624  127.045738
# 4     성동구             G010_(고정2)3_성수동갈비골목    미세먼지  37.547321  127.042847
# ...   ...                             ...     ...        ...         ...
# 1251  성동구     D034_(회전)_용답동 180 전농천하천위기관리    치수방재  37.561694  127.055472
# 1252  성동구             D014_(회전)_용답꽃공원앞-04    치수방재  37.562015  127.055604
# 1253  성동구      D032_(회전)_사근동 235-12 사근사거리    치수방재  37.562175  127.049247
# 1254  성동구           D025_(회전)_용답길 86용답육갑문    치수방재  37.562283  127.050692
# 1255  성동구  D036_(회전)_천호대로 342(성동구견인차량보관소)    치수방재  37.562380  127.055765
#
#       CCTV 수량       수정 일시
# 0           1  2021-12-07
# 1           1  2021-12-07
# 2           1  2021-12-07
# 3           1  2021-12-07
# 4           1  2021-12-07
# ...       ...         ...
# 1251        1  2021-12-07
# 1252        1  2021-12-07
# 1253        1  2021-12-07
# 1254        1  2021-12-07
# 1255        1  2021-12-07
#
# [1256 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구      1256 non-null   object
#  1   안심 주소    1256 non-null   object
#  2   CCTV 용도  1256 non-null   object
#  3   위도       1256 non-null   float64
#  4   경도       1256 non-null   float64
#  5   CCTV 수량  1256 non-null   int64
#  6   수정 일시    1256 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 68.8+ KB

# %%
df.columns
# Out:
# Index(['자치구', '안심 주소', 'CCTV 용도', '위도', '경도', 'CCTV 수량', '수정 일시'], dtype='object')

# %%
# 지도에 cctv 위치 표시하기
import folium

m = folium.Map(location=[37.5544988,127.0404364], zoom_start = 15)

for i in range(len(df)):
  folium.Marker(location = [df.위도[i],df.경도[i]],
              icon = folium.Icon(color = 'blue', icon='flag'),
              popup = df['안심 주소'][i],
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9c1d3e42b532230ae608964b51b8824 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9c1d3e42b532230ae608964b51b8824&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f9c1d3e42b532230ae608964b51b8824 = L.map(
#                 &quot;map_f9c1d3e42b532230ae608964b51b8824&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b475c2b53706affcd68e4608f120efae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9c1d3e42b532230ae608964b51b8824);
#
#
#             var marker_9d5dc611b3122f67385e3fd5f24860d6 = L.marker(
#                 [37.53473282, 127.0568008],
#                 {}
#             ).addTo(map_f9c1d3e42b532230ae608964b51b8824);
#
#
#             var icon_ad949f75e007d3fa7ef8627ebdc4e45d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d5dc611b3122f67385e3fd5f24860d6.setIcon(icon_ad949f75e007d3fa7ef8627ebdc4e45d);
#
#
#         var popup_05d742de52bca090da7ab4fcf9aa4e04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_92bd909b59df77124c79e5a9bc152b27 = $(`&lt;div id=&quot;html_92bd909b59df77124c79e5a9bc152b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;G044_(고정2)6_골목길(동)&lt;/div&gt;`)[0];
#             popup_05d742de52bca090da7ab4fcf9aa4e04.setContent(html_92bd909b59df77124c79e5a9bc152b27);
#
#
#         marker_9d5dc611b3122f67385e3fd5f24860d6.bindPopup(popup_05d742de52bca090da7ab4fcf9aa4e04)
#         ;
#
#
#
#
#             var marker_dc75ae207ff572bd7ca8151e4104df6b = L.marker(
#                 [37.53902817, 127.0473709],
#                 {}
#             ).addTo(map_f9c1d3e42b532230ae608964b51b8824);
#
#
#             var icon_eb6929087f26e6937499c83f4ee62845 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc75ae207ff572bd7ca8151e4104df6b.setIcon(icon_eb6929087f26e6937499c83f4ee62845);
#
#
#         var popup_750e80ccc726c97a46ae6f8c31e925e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dc1caae2e31ed89556f457c0187e6af0 = $(`&lt;div id=&quot;html_dc1caae2e31ed89556f457c0187e6af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;**C362_(회전)_성수동1가 95&lt;/div&gt;`)[0];
#             popup_750e80ccc726c97a46ae6f8c31e925e8.setContent(html_dc1caae2e31ed89556f457c0187e6af0);
#
#
#         marker_dc75ae207ff572bd7ca8151e4104df6b.bindPopup(popup_750e80ccc726c97a46ae6f8c31e925e8)
#         ;
#
#
#
#
#             var marker_f5a934962c37fdd2ebbfcfce5749eeb6 = L.marker(
#                 [37.54308319, 127.0552902],
#                 {}
#             ).addTo(map_f9c1d3e42b532230ae608964b51b8824);
#
#
#             var icon_0f33c36e64b4df800783bc4b3923bf49 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f5a934962c37fdd2ebbfcfce5749eeb6.setIcon(icon_0f33c36e64b4df800783bc4b3923bf49);
#
#
#         var popup_cfe6c0e0e56c70bf55e62dae5ffb4e9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b07fa4152a00be8327321fa3503740d0 = $(`&lt;div id=&quot;html_b07fa4152a00be8327321fa3503740d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;G049_(고정2)3_자그마치&lt;/div&gt;`)[0];
#             popup_cfe6c0e0e56c70bf55e62dae5ffb4e9c.setContent(html_b07fa4152a00be8327321fa3503740d0);
#
#
#         marker_f5a934962c37fdd2ebbfcfce5749eeb6.bindPopup(popup_cfe6c0e0e56c70bf55e62dae5ffb4e9c)
#         ;
#
#
#
#
#             var marker_745112be1c7e7b7db7d3d1f8751ebacf = L.marker(
#                 [37.54562378, 127.0457382],
#                 {}
#             ).addTo(map_f9c1d3e42b532230ae608964b51b8824);
#
#
#             var icon_7f3d99d819ae0e72dfa9867996369cb1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_745112be1c7e7b7db7d3d1f8751ebacf.setIcon(icon_7f3

# %%
df.sample(10)
# Out:
#       자치구                              안심 주소   CCTV 용도         위도          경도  \
# 145   성동구        C747_(고정3)7_옥정초방향_옥수동 367-9      도심공원  37.541132  127.017062
# 678   성동구     C218_(고정3)3_무학교회_왕십리로21길 31-24      도심공원  37.560169  127.031670
# 793   성동구              C244_(고정2)9_용답동 182-9      도심공원  37.562557  127.056038
# 384   성동구               C892_(고정2)7_송정10길 19      도심공원  37.549023  127.066956
# 50    성동구                C068_(고정3)3_골목길(남동)      도심공원  37.535870  127.059036
# 636   성동구              C246_(고정1)7_자동차산업정보센터      도심공원  37.558773  127.066750
# 445   성동구  C572_(고정2)4_뚝섬체육공원_왕십리로16가길 10-15      도심공원  37.550346  127.045113
# 1127  성동구             W082_(고정4)2_독서당로 285-1  쓰레기 무단투기  37.547909  127.020950
# 403   성동구              C051_(회전)_응봉동 193-192      도심공원  37.549442  127.031082
# 1185  성동구                W091_(고정2)1_무학봉길 86  쓰레기 무단투기  37.561710  127.031632
#
#       CCTV 수량       수정 일시
# 145         1  2021-12-07
# 678         1  2021-12-07
# 793         1  2021-12-07
# 384         1  2021-12-07
# 50          1  2021-12-07
# 636         1  2021-12-07
# 445         1  2021-12-07
# 1127        1  2021-12-07
# 403         1  2021-12-07
# 1185        1  2021-12-07

# %%
# CCTV 용도의 값을 중복없이 추출해보기
df['CCTV 용도'].unique()
# Out:
# array(['미세먼지', '도심공원', '불법주정차', '쓰레기 무단투기', '자전거보관소', '치수방재'],
#       dtype=object)

# %%
# 불법주정차 단속용 CCTV데이터만 추출
df_car =  df[df['CCTV 용도'] == '불법주정차']
df_car

# %%
# 인덱스 재지정
df_car.reset_index(drop=True, inplace= True)
df_car
# Out:
#      자치구                             안심 주소 CCTV 용도         위도          경도  \
# 0    성동구       P061_(고정4)7_천지인한의원_성덕정길 106   불법주정차  37.537220  127.055290
# 1    성동구    P035_(고정3)3_성수119안전센터_뚝섬로17길 3   불법주정차  37.537746  127.059616
# 2    성동구          P058_(고정3)4_선출빌딩_성덕정길 75   불법주정차  37.538063  127.051666
# 3    성동구         P062_(고정4)7_성원중학교_뚝섬로 400   불법주정차  37.538720  127.054907
# 4    성동구           P044_(회전)_성수동2가 혜미슈퍼 주변   불법주정차  37.541283  127.059441
# ..   ...                               ...     ...        ...         ...
# 98   성동구         P071_(고정2)1_청계천_마장로39길 33   불법주정차  37.568470  127.043671
# 99   성동구        P015_(고정1)1_도선사거리_고산자로 330   불법주정차  37.569138  127.037521
# 100  성동구  P080_(고정3)4_텐즈힐2단지 아파트_상왕십리동2-19   불법주정차  37.570282  127.026497
# 101  성동구       P016_(고정2)3_제2마장교_마장로35길 76   불법주정차  37.570602  127.042519
# 102  성동구         P075_(고정1)9_삼공빌딩_청계천로 422   불법주정차  37.571037  127.023537
#
#      CCTV 수량       수정 일시
# 0          1  2021-12-07
# 1          1  2021-12-07
# 2          1  2021-12-07
# 3          1  2021-12-07
# 4          1  2021-12-07
# ..       ...         ...
# 98         1  2021-12-07
# 99         1  2021-12-07
# 100        1  2021-12-07
# 101        1  2021-12-07
# 102        1  2021-12-07
#
# [103 rows x 7 columns]

# %%
import folium

m = folium.Map(location=[37.5544988,127.0404364], zoom_start = 15, tiles='cartodb positron')

for i in range(len(df_car)):
  folium.Marker(location = [df_car.위도[i],df_car.경도[i]],
              icon = folium.Icon(color = 'red', icon='search'),
              popup = df_car['안심 주소'][i],
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7b749e1b35ef2fc7f7b92c8b9659b83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7b749e1b35ef2fc7f7b92c8b9659b83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c7b749e1b35ef2fc7f7b92c8b9659b83 = L.map(
#                 &quot;map_c7b749e1b35ef2fc7f7b92c8b9659b83&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a283f560267c2aaa72483e843b8f6282 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c7b749e1b35ef2fc7f7b92c8b9659b83);
#
#
#             var marker_3fd37dfad08d8d95bf549e501553adca = L.marker(
#                 [37.53722, 127.0552902],
#                 {}
#             ).addTo(map_c7b749e1b35ef2fc7f7b92c8b9659b83);
#
#
#             var icon_8f6da621896959279c10dbe162894e7d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3fd37dfad08d8d95bf549e501553adca.setIcon(icon_8f6da621896959279c10dbe162894e7d);
#
#
#         var popup_11258f17d2c36b1b2ba4e8bc7809b6ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7958bba562e44cf666f8fbd9c03f8882 = $(`&lt;div id=&quot;html_7958bba562e44cf666f8fbd9c03f8882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P061_(고정4)7_천지인한의원_성덕정길 106&lt;/div&gt;`)[0];
#             popup_11258f17d2c36b1b2ba4e8bc7809b6ff.setContent(html_7958bba562e44cf666f8fbd9c03f8882);
#
#
#         marker_3fd37dfad08d8d95bf549e501553adca.bindPopup(popup_11258f17d2c36b1b2ba4e8bc7809b6ff)
#         ;
#
#
#
#
#             var marker_5cfb2b37fdd58b617b03d2054aafd7a9 = L.marker(
#                 [37.53774643, 127.0596161],
#                 {}
#             ).addTo(map_c7b749e1b35ef2fc7f7b92c8b9659b83);
#
#
#             var icon_2a141ee0af7e9cbba0ee48b3f9cf300d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5cfb2b37fdd58b617b03d2054aafd7a9.setIcon(icon_2a141ee0af7e9cbba0ee48b3f9cf300d);
#
#
#         var popup_7dd2edc1e9f94991e3d0585d84a198b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2e731a8c7037818611b979ff568f1aba = $(`&lt;div id=&quot;html_2e731a8c7037818611b979ff568f1aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P035_(고정3)3_성수119안전센터_뚝섬로17길 3&lt;/div&gt;`)[0];
#             popup_7dd2edc1e9f94991e3d0585d84a198b7.setContent(html_2e731a8c7037818611b979ff568f1aba);
#
#
#         marker_5cfb2b37fdd58b617b03d2054aafd7a9.bindPopup(popup_7dd2edc1e9f94991e3d0585d84a198b7)
#         ;
#
#
#
#
#             var marker_7642528562b451a8b502fb591b41c32f = L.marker(
#                 [37.53806305, 127.0516663],
#                 {}
#             ).addTo(map_c7b749e1b35ef2fc7f7b92c8b9659b83);
#
#
#             var icon_f34279a761111589d9cdf85720ffbbb9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7642528562b451a8b502fb591b41c32f.setIcon(icon_f34279a761111589d9cdf85720ffbbb9);
#
#
#         var popup_579f3172eade7123aff1ec69ebba33a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0bc4b928ba6454ba48f9d75e87605dc5 = $(`&lt;div id=&quot;html_0bc4b928ba6454ba48f9d75e87605dc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P058_(고정3)4_선출빌딩_성덕정길 75&lt;/div&gt;`)[0];
#             popup_579f3172eade7123aff1ec69ebba33a1.setContent(html_0bc4b928ba6454ba48f9d75e87605dc5);
#
#
#         marker_7642528562b451a8b502fb591b41c32f.bindPopup(popup_579f3172eade7123aff1ec69ebba33a1)
#         ;
#
#
#
#
#             var marker_6ac92d623f301f17a8b8c2ec18dd41f4 = L.marker(
#                 [37.53871972, 127.0549075],
#                 {}
#             ).addTo(map_c7b749e1b35ef2fc7f7b92c8b9659b83);
#
#
#             var icon_ce76dbc2a5d5d2515d58dde56edd7e55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&q
